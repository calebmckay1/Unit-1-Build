# %% [markdown]
# <a href="https://colab.research.google.com/github/calebmckay1/Unit-1-Build/blob/master/Unit_1_Build_Week_Project_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_15 = pd.read_csv('https://raw.githubusercontent.com/calebmckay1/Unit-1-Build/master/2015.csv')
df_16 = pd.read_csv('https://raw.githubusercontent.com/calebmckay1/Unit-1-Build/master/2016.csv')
df_17 = pd.read_csv('https://raw.githubusercontent.com/calebmckay1/Unit-1-Build/master/2017.csv')
df_18 = pd.read_csv('https://raw.githubusercontent.com/calebmckay1/Unit-1-Build/master/2018.csv')
df_19 = pd.read_csv('https://raw.githubusercontent.com/calebmckay1/Unit-1-Build/master/2019.csv')



# import dataframe from github. Sourced from Kaggle.

# %%
df_15['year'] = 2015
df_16['year'] = 2016
df_17['year'] = 2017
df_18['year'] = 2018
df_19['year'] = 2019

# added year column to view trends in future visualizations.

# %%
df_16 = df_16.drop(['Upper Confidence Interval', 'Lower Confidence Interval',
                    'Happiness Rank','Dystopia Residual'], axis=1)
df_15 = df_15.drop(['Standard Error','Happiness Rank','Dystopia Residual'], axis=1)
df_17 = df_17.drop(['Whisker.high', 'Whisker.low','Happiness.Rank','Dystopia.Residual'], axis=1)
df_18 = df_18.drop(['Overall rank'], axis=1)
df_19 = df_19.drop(['Overall rank'], axis=1)

# dropped unimportant columns.

# %%
df_17 = df_17.rename(columns={'Happiness.Score': 'Happiness Score',
       'Economy..GDP.per.Capita.':'Economy (GDP per Capita)', 
       'Health..Life.Expectancy.':'Health (Life Expectancy)',
       'Trust..Government.Corruption.':'Trust (Government Corruption)'})

# changed column names to match so we can combine them all later.

# %%
df_18 = df_18.rename(columns= {'Country or region': 'Country', 'Score':'Happiness Score',
       'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family', 
       'Healthy life expectancy': 'Health (Life Expectancy)',
       'Freedom to make life choices': 'Freedom',
       'Perceptions of corruption': 'Trust (Government Corruption)'})

# changed column names to match so we can combine them all later.

# %%
df_19 = df_19.rename(columns= {'Country or region': 'Country', 'Score':'Happiness Score',
       'GDP per capita':'Economy (GDP per Capita)', 'Social support':'Family', 
       'Healthy life expectancy': 'Health (Life Expectancy)',
       'Freedom to make life choices': 'Freedom',
       'Perceptions of corruption': 'Trust (Government Corruption)'})

# changed column names to match so we can merge later.

# %%
df_17['Region'] = df_16['Region']
df_18['Region'] = df_16['Region']
df_19['Region'] = df_16['Region']

# added the missing Region column to the dataframes using 2016's region column.

# %%
world_happiness = pd.concat([df_15, df_16, df_17, df_18, df_19])

# combined all the years into one dataframe.

# %%
world_happiness = world_happiness.rename(columns= {'Happiness Score':'Score',
       'Economy (GDP per Capita)':'GDP', 
       'Health (Life Expectancy)':'Health',
       'Trust (Government Corruption)':'Trust'})

# shortened the column headers to make the correlation matrix easier to read.

# %%
world_happiness_corr = world_happiness.corr()

# created a correlation matrix called 'world_happiness_corr'

# %%
world_happiness_corr.style.background_gradient(cmap='coolwarm')
world_happiness_corr.style.background_gradient(cmap='coolwarm').set_precision(1)

# viewed the correlation matrix with a colorscheme to get an easier view of 
# the higher and lower correlations.
# Out:
# <style  type="text/css" >
#     #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col1 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col2 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col3 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col4 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col5 {
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col6 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row0_col7 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col0 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col2 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col3 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col4 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col5 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col6 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row1_col7 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col0 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col1 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col3 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col4 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col5 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col6 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row2_col7 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col0 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col1 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col2 {
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col4 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col5 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col6 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row3_col7 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col0 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col1 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col2 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col3 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col5 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col6 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row4_col7 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col0 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col1 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col2 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col3 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col4 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col6 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row5_col7 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col0 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col5 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row6_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row7_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row7_col1 {
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row7_col2 {
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }    #T_c6ad56ee_a13b_11ea_b99f_0242ac1c0002row7_col3 {
#             background-color:  #5f7fe8;
#             color:  #000000;

# %%
world_happiness_table = pd.pivot_table(world_happiness, values='Score', 
                     index=['Region'], 
                     columns='year')

# created a pivot table using Score as the main target, with region and 
# year as variables.

# %%
import seaborn as sns
sns.heatmap(world_happiness_table, cmap='plasma');

# plotted the pivot table into a heatmap to view 'happiness score' trends
# from 2015 to 2019

# %%
plt.figure(figsize=(14,5))
plt.plot(df_19['Happiness Score'],df_19['Economy (GDP per Capita)'], label= 'GDP', color= 'green')
plt.plot(df_19['Happiness Score'],df_19['Family'], label= 'Family Support', color= 'blue')
plt.plot(df_19['Happiness Score'],df_19['Health (Life Expectancy)'], label= 'Health', color= 'black')
plt.plot(df_19['Happiness Score'],df_19['Freedom'], label= 'Freedom', color= 'purple')
plt.plot(df_19['Happiness Score'],df_19['Trust (Government Corruption)'], label= 'Trust in Government', color= 'orange')
plt.plot(df_19['Happiness Score'],df_19['Generosity'], label= 'Generosity', color= 'red')

plt.xlabel('Happiness Score (1-10)')
plt.ylabel('Contributing Factors To Happiness')
plt.title('World Happiness in 2019')

plt.grid()
plt.legend()
plt.show()

# plotted the varibles that contribute to happiness to visually see the correlations.

# %%
import plotly
import plotly.graph_objs as go
from plotly.offline import *

# imported plotly for offline use (had to in order to run next cell)

# %%
global_happiness = dict(type = 'choropleth',
             locations = world_happiness['Country'],
             locationmode = 'country names',
             z = world_happiness['Score'],
             text = world_happiness['Country'],
             colorscale = 'plasma',
             autocolorscale=False,
             colorbar= {'title':'Happiness'})
layout = dict(title = 'Average Happiness on 1-10 Scale',
              geo = dict(showframe = False, 
                         projection = {'type':'equirectangular'}))
choromap1 = go.Figure(data= [global_happiness], layout = layout)
iplot(choromap1)

# created a heatmap called 'choromap1' that displays the average happiness score
# of each country.
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="75aaf63f-b942-496f-b8c2-6e12b8c6581c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("75aaf63f-b942-496f-b8c2-6e12b8c6581c")) {
#                     Plotly.newPlot(
#                         '75aaf63f-b942-496f-b8c2-6e12b8c6581c',
#                         [{"autocolorscale": false, "colorbar": {"title": {"text": "Happiness"}}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "locationmode": "country names", "locations": ["Switzerland", "Iceland", "Denmark", "Norway", "Canada", "Finland", "Netherlands", "Sweden", "New Zealand", "Australia", "Israel", "Costa Rica", "Austria", "Mexico", "United States", "Brazil", "Luxembourg", "Ireland", "Belgium", "United Arab Emirates", "United Kingdom", "Oman", "Venezuela", "Singapore", "Panama", "Germany", "Chile", "Qatar", "France", "Argentina", "Czech Republic", "Uruguay", "Colombia", "Thailand", "Saudi Arabia", "Spain", "Malta", "Taiwan", "Kuwait", "Suriname", "Trinidad and Tobago", "El Salvador", "Guatemala", "Uzbekistan", "Slovakia", "Japan", "South Korea", "Ecuador", "Bahrain", "Italy", "Bolivia", "Moldova", "Paraguay", "Kazakhstan", "Slovenia", "Lithuania", "Nicaragua", "Peru", "Belarus", "Poland", "Malaysia", "Croatia", "Libya", "Russia", "Jamaica", "North Cyprus", "Cyprus", "Algeria", "Kosovo", "Turkmenistan", "Mauritius", "Hong Kong", "Estonia", "Indonesia", "Vietnam", "Turkey", "Kyrgyzstan", "Nigeria", "Bhutan", "Azerbaijan", "Pakistan", "Jordan", "Montenegro", "China", "Zambia", "Romania", "Serbia", "Portugal", "Latvia", "Philippines", "Somaliland region", "Morocco", "Macedonia", "Mozambique", "Albania", "Bosnia and Herzegovina", "Lesotho", "Dominican Republic", "Laos", "Mongolia", "Swaziland", "Greece", "Lebanon", "Hungary", "Honduras", "Tajikistan", "Tunisia", "Palestinian Territories", "Bangladesh", "Iran", "Ukraine", "Iraq", "South Africa", "Ghana", "Zimbabwe", "Liberia", "India", "Sudan", "Haiti", "Congo (Kinshasa)", "Nepal", "Ethiopia", "Sierra Leone", "Mauritania", "Kenya", "Djibouti", "Armenia", "Botswana", "Myanmar", "Georgia", "Malawi", "Sri Lanka", "Cameroon", "Bulgaria", "Egypt", "Yemen", "Angola", "Mali", "Congo (Brazzaville)", "Comoros", "Uganda", "Senegal", "Gabon", "Niger", "Cambodia", "Tanzania", "Madagascar", "Central African Republic", "Chad", "Guinea", "Ivory Coast", "Burkina Faso", "Afghanistan", "Rwanda", "Benin", "Syria", "Burundi", "Togo", "Denmark", "Switzerland", "Iceland", "Norway", "Finland", "Canada", "Netherlands", "New Zealand", "Australia", "Sweden", "Israel", "Austria", "United States", "Costa Rica", "Puerto Rico", "Germany", "Brazil", "Belgium", "Ireland", "Luxembourg", "Mexico", "Singapore", "United Kingdom", "Chile", "Panama", "Argentina", "Czech Republic", "United Arab Emirates", "Uruguay", "Malta", "Colombia", "France", "Thailand", "Saudi Arabia", "Taiwan", "Qatar", "Spain", "Algeria", "Guatemala", "Suriname", "Kuwait", "Bahrain", "Trinidad and Tobago", "Venezuela", "Slovakia", "El Salvador", "Malaysia", "Nicaragua", "Uzbekistan", "Italy", "Ecuador", "Belize", "Japan", "Kazakhstan", "Moldova", "Russia", "Poland", "South Korea", "Bolivia", "Lithuania", "Belarus", "North Cyprus", "Slovenia", "Peru", "Turkmenistan", "Mauritius", "Libya", "Latvia", "Cyprus", "Paraguay", "Romania", "Estonia", "Jamaica", "Croatia", "Hong Kong", "Somalia", "Kosovo", "Turkey", "Indonesia", "Jordan", "Azerbaijan", "Philippines", "China", "Bhutan", "Kyrgyzstan", "Serbia", "Bosnia and Herzegovina", "Montenegro", "Dominican Republic", "Morocco", "Hungary", "Pakistan", "Lebanon", "Portugal", "Macedonia", "Vietnam", "Somaliland Region", "Tunisia", "Greece", "Tajikistan", "Mongolia", "Laos", "Nigeria", "Honduras", "Iran", "Zambia", "Nepal", "Palestinian Territories", "Albania", "Bangladesh", "Sierra Leone", "Iraq", "Namibia", "Cameroon", "Ethiopia", "South Africa", "Sri Lanka", "India", "Myanmar", "Egypt", "Armenia", "Kenya", "Ukraine", "Ghana", "Congo (Kinshasa)", "Georgia", "Congo (Brazzaville)", "Senegal", "Bulgaria", "Mauritania", "Zimb ...
